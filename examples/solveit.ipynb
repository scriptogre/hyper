# %%
# %load_ext hyperhtml.ipython

# %%
names = ['Ada', 'Lin', 'Chris']

# %%
# %%hyper
# names: list[str]
# ---
# <main style="font: 20px system-ui; padding: 24px">
# <h1>Hello from Hyper</h1>
# <ul>
#     for name in names:
#         <li>Hello, {name}!</li>
#     end
# </ul>
# </main>

# %%
print(Preview(names=['Answer.AI']))
